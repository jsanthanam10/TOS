# %%
import requests
import pandas as pd
import sqlite3  # Import the sqlite3 library
import os


def fetch_tosdr_data():
    # Initialize an empty list to store cases
    cases_list = []

    # Loop through the available pages
    for page_number in range(1, 4):  # Adjust the range as needed
        # Make the API request
        response = requests.get(
            f"https://api.tosdr.org/case/v1/?page={page_number}").json()

        # Loop through each case and append to list
        for case in response["parameters"]["cases"]:
            cases_list.append({
                'id': case.get('id', None),
                'title': case.get('title', None),
                'description': case.get('description', None),
                'classification': case.get('classification', {}).get('human', None)
            })

    # Convert the list of dictionaries to a DataFrame
    df = pd.DataFrame(cases_list)
    
    # Save to CSV (optional)
    df.to_csv("../data/tosdr_data.csv", index=False)

    # Save to SQLite database
    save_to_db(df)


# Function to save DataFrame to SQLite database
def save_to_db(df):
    # Create or open SQLite database
    conn = sqlite3.connect('../data/tosdr_data.db')

    # Save DataFrame to SQLite database
    df.to_sql('tosdr_cases', conn, if_exists='replace', index=False)

    # Commit and close connection
    conn.commit()
    conn.close()


if __name__ == "__main__":
    fetch_tosdr_data()

# %%
import pandas as pd
pd.set_option('display.max_colwidth', None)

# %%
df = pd.read_csv("../data/tosdr_data.csv")
df
# Out:
#       id  \
# 0    175
# 1    130
# 2    129
# 3    237
# 4    173
# ..   ...
# 248  146
# 249  293
# 250  228
# 251  504
# 252  233
#
#                                                                                                                    title  \
# 0                                                                          You can delete your content from this service
# 1                                          A license is kept on user-generated content even after you close your account
# 2                                                                              This service tracks you on other websites
# 3                                                              You agree to comply with the law of the service's country
# 4                                     This service retains rights to your content even after you stop using your account
# ..                                                                                                                   ...
# 248  You agree to defend, indemnify, and hold the service harmless in case of a claim related to your use of the service
# 249        This service assumes no liability for any losses or damages resulting from any matter relating to the service
# 250                                                  Information is provided about what kind of information they collect
# 251                                   Your personal data is used for automated decision-making, profiling or AI training
# 252                       Do Not Track (DNT) headers are ignored and you are tracked anyway even if you set this header.
#
#                                                                                                                                                                                                                                                                                                                                                                         description  \
# 0                                                                                                                                                                                                                                                                            You can ask the service to remove your content at any time, and it's deleted within a reasonable time.
# 1                                                                                                                                                                      The service may still use your content and display it after you stopped using it by closing your account. The case applies to terms requiring users to grant them a perpetual license over that content.\r\n
# 2                                                                                                                                                                                                                                         The service may use tracking technologies in third-party websites to track your online activity while you aren't visiting their Site.\r\n
# 3                                                                                                                                                                                                                                                    By using the service, you agree to comply with the applicable laws of the service's jurisdiction, regardless of your location.
# 4                                                                                                                                                                           The service may still use your content and display it after you stopped using it by closing your account, since you granted them a perpetual or (in some cases) an unlimited license over that content.
# ..                                                                                                                                                                                                                                                                                                                                                                              ...
# 248                                                                                                                                                                                                                                                                                                                                                                             NaN
# 249                                                                                                                                      The service assumes no liability for any damages the user incurs, including tangible (e.g. profits) and intangible losses (e.g. data), resulting from the use or inability to use the service or any other matter relating to the service.
# 250                                                                                                                                                                                                                                                                The Privacy Policy describes in detail the data collected through the website and through the services provided.
# 251  Personal data or content you share with the service may be processed to make decisions by automated means without human involvement. This includes profiling, which is any form of automated processing of your information to analyse or predict things like your economic situation, health, personal preferences or interests; as well as Artificial Intelligence training.
# 252                                                                                                                                                                                                                                      Even though the Do Not Track (DNT) header was not implemented perfectly, services should not track users whose browsers send a DNT header.
#
#     classification
# 0             good
# 1              bad
# 2              bad
# 3          neutral
# 4              bad
# ..             ...
# 248        neutral
# 249        neutral
# 250           good
# 251        blocker
# 252        neutral
#
# [253 rows x 4 columns]
